# %%
import pandas as pd

# %%
df_today = pd.read_csv('data/2025/2025_05_24_game.csv')

# %%
import requests
def inning_run_1(game_id):
    url = f"https://statsapi.mlb.com/api/v1/game/{game_id}/linescore"
    try:
        response = requests.get(url)
        data = response.json()

        inning_scores = data.get("innings", [])
        if len(inning_scores) >= 1:
            home_runs = inning_scores[0]['home']['runs']
            away_runs = inning_scores[0]['away']['runs']
            return 1 if (home_runs > 0 or away_runs > 0) else 0
        return 0
    except Exception as e:
        print(f"Error con gamePk {game_id}: {e}")
        return 0

# %%
import requests

url = f"https://statsapi.mlb.com/api/v1/game/{777809}/linescore"
try:
  response = requests.get(url)
except Exception as e:
  pass
print(response.content)
# Out:
# b'{"copyright":"Copyright 2025 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt","currentInning":3,"currentInningOrdinal":"3rd","inningState":"Top","inningHalf":"Top","isTopInning":true,"scheduledInnings":9,"innings":[{"num":1,"ordinalNum":"1st","home":{"runs":2,"hits":3,"errors":0,"leftOnBase":1},"away":{"runs":2,"hits":2,"errors":0,"leftOnBase":1}},{"num":2,"ordinalNum":"2nd","home":{"runs":0,"hits":0,"errors":0,"leftOnBase":0},"away":{"runs":0,"hits":0,"errors":0,"leftOnBase":0}},{"num":3,"ordinalNum":"3rd","home":{"hits":0,"errors":0,"leftOnBase":0},"away":{"hits":1,"errors":0,"leftOnBase":0}}],"teams":{"home":{"runs":2,"hits":3,"errors":0,"leftOnBase":1},"away":{"runs":2,"hits":3,"errors":0,"leftOnBase":1}},"defense":{"pitcher":{"id":690928,"fullName":"Hunter Dobbins","link":"/api/v1/people/690928"},"catcher":{"id":665966,"fullName":"Carlos Narv\xc3\xa1ez","link":"/api/v1/people/
# ...

# %%
df_today
# Out:
#     game_id             home_team              away_team  \
# 0    777809        Boston Red Sox      Baltimore Orioles
# 1    777790        Boston Red Sox      Baltimore Orioles
# 2    777788       Minnesota Twins     Kansas City Royals
# 3    777786   St. Louis Cardinals   Arizona Diamondbacks
# 4    777793  Washington Nationals   San Francisco Giants
# 5    777794    Pittsburgh Pirates      Milwaukee Brewers
# 6    777791       Cincinnati Reds           Chicago Cubs
# 7    777787        Houston Astros       Seattle Mariners
# 8    777803        Atlanta Braves       San Diego Padres
# 9    777792     Chicago White Sox          Texas Rangers
# 10   777782      Colorado Rockies       New York Yankees
# 11   777795        Tampa Bay Rays      Toronto Blue Jays
# 12   777796        Detroit Tigers    Cleveland Guardians
# 13   777789         New York Mets    Los Angeles Dodgers
# 14   777784             Athletics  Philadelphia Phillies
# ...

# %%
# Models

import os
import joblib

path_model = './model'  # Carpeta donde están los .pkl
models = {}

for file_ in os.listdir(path_model):
    if file_.endswith('.pkl'):
        
        name = file_.replace('.pkl', '')
        models[name] = joblib.load(os.path.join(path_model, file_))

# %%
models
# Out:
# {'LogisticRegression': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model', LogisticRegression(max_iter=1000))]),
#  'RandomForest': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model',
#                   RandomForestClassifier(max_features=0.1, min_samples_leaf=4,
#                                          n_estimators=300, random_state=42))]),
#  'Naive_Bayes': Pipeline(steps=[('scaler', StandardScaler()), ('model', GaussianNB())]),
#  'SVM': Pipeline(steps=[('scaler', StandardScaler()), ('model', SVC())]),
#  'gradient_boosting_ft': Pipeline(steps=[('scaler', StandardScaler()),
#                  ('model',
#                   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                 colsample_bylevel=None, colsample_bynode=None,
#                                 colsample_bytree=0.8, device=None,
#                                 early_stopping_rounds=None,
# ...

# %%
model =models['Gradient _Boosting']

# %%
features = [
    "home_pitcher_true_freq", "away_pitcher_true_freq",
    "home_pitcher_vs_team_freq", "away_pitcher_vs_team_freq",
    "home_pitcher_vs_team_freq_count", "away_pitcher_vs_team_freq_count",
    "home_pitcher_last3_freq_1st", "away_pitcher_last3_freq_1st",
    "home_pitcher_momentum", "away_pitcher_momentum",
    "home_pitcher_vs_away_team_momentum", "away_pitcher_vs_home_team_momentum",
    "home_team_inning1_scaled", "away_team_inning1_scaled",
    "umpire_inning1_scaled", "stadium_inning1_scaled"
]

# %%
threshold = 0.95
X = df_today[features]
y_proba = model.predict_proba(X)
y_pred = (y_proba[:, 1] >= threshold).astype(int)
# Crear DataFrame copia con columnas nuevas
df_result = df_today.copy()
df_result[f'proba_0'] = y_proba[:, 0]  # probabilidad clase 0
df_result[f'proba_1'] = y_proba[:, 1]  # probabilidad clase 1
df_result[f'pred'] = y_pred
# df_filtrado = df_result[(df_result[f'proba_1'] >= threshold)]
df_filtrado = df_result[(df_result[f'proba_1'] >= threshold) | (df_result[f'proba_0'] >= threshold)]
columnas_resultado = [
        'game_id', 'home_team', 'away_team',
        f'proba_0', f'proba_1', f'pred'
    ] + [col for col in features if col in df_filtrado.columns]

# %%
from IPython.display import display
columnas_a_mostrar = ['home_team', 'away_team', 'proba_0', 'proba_1', 'pred']

display(df_filtrado[columnas_a_mostrar])
display(df_result[columnas_a_mostrar])
# Out:
#               home_team              away_team   proba_0   proba_1  pred
# 1        Boston Red Sox      Baltimore Orioles  0.980742  0.019258     0
# 2       Minnesota Twins     Kansas City Royals  0.972816  0.027184     0
# 3   St. Louis Cardinals   Arizona Diamondbacks  0.992858  0.007142     0
# 5    Pittsburgh Pirates      Milwaukee Brewers  0.087909  0.912091     1
# 6       Cincinnati Reds           Chicago Cubs  0.007393  0.992607     1
# 7        Houston Astros       Seattle Mariners  0.950748  0.049252     0
# 8        Atlanta Braves       San Diego Padres  0.063979  0.936021     1
# 9     Chicago White Sox          Texas Rangers  0.003154  0.996846     1
# 11       Tampa Bay Rays      Toronto Blue Jays  0.910933  0.089067     0
# 12       Detroit Tigers    Cleveland Guardians  0.989221  0.010779     0
# 13        New York Mets    Los Angeles Dodgers  0.991634  0.008366     0
# 14            Athletics  Philadelphia Phillies  0.978199  0.021801     0
# ...

# %%
import pandas as pd
import numpy as np
import random

# Datos originales
original_data = {
    'home_team': ['Boston Red Sox', 'Minnesota Twins', 'St. Louis Cardinals', 'Pittsburgh Pirates', 
                  'Cincinnati Reds', 'Houston Astros', 'Atlanta Braves', 'Chicago White Sox',
                  'Tampa Bay Rays', 'Detroit Tigers', 'New York Mets', 'Athletics', 'Los Angeles Angels'],
    'away_team': ['Baltimore Orioles', 'Kansas City Royals', 'Arizona Diamondbacks', 'Milwaukee Brewers',
                  'Chicago Cubs', 'Seattle Mariners', 'San Diego Padres', 'Texas Rangers',
                  'Toronto Blue Jays', 'Cleveland Guardians', 'Los Angeles Dodgers', 'Philadelphia Phillies', 'Miami Marlins']
}

# Rankings aproximados de equipos (1=mejor, 30=peor) - basado en rendimiento típico
team_strength = {
    # Equipos fuertes
    'Los Angeles Dodgers': 95, 'Houston Astros': 92, 'Atlanta Braves': 90, 
    'New York Mets': 88, 'Philadelphia Phillies': 87, 'Toronto Blue Jays': 86,
    'Milwaukee Brewers': 85, 'San Diego Padres': 84, 'Tampa Bay Rays': 83,
    'Baltimore Orioles': 82, 'Minnesota Twins': 81, 'Cleveland Guardians': 80,
    
    # Equipos medios
    'Boston Red Sox': 78, 'St. Louis Cardinals': 77, 'Seattle Mariners': 76,
    'Chicago Cubs': 75, 'Texas Rangers': 74, 'Arizona Diamondbacks': 73,
    'Cincinnati Reds': 72, 'Miami Marlins': 70,
    
    # Equipos más débiles
    'Pittsburgh Pirates': 68, 'Kansas City Royals': 67, 'Los Angeles Angels': 66,
    'Detroit Tigers': 65, 'Chicago White Sox': 62, 'Athletics': 60
}

def calculate_win_probability(home_team, away_team, home_advantage=3):
    """
    Calcula probabilidad de victoria basada en strength rating
    """
    home_strength = team_strength.get(home_team, 75) + home_advantage
    away_strength = team_strength.get(away_team, 75)
    
    # Diferencia de strength
    diff = home_strength - away_strength
    
    # Convertir a probabilidad usando función logística
    # Ajustamos para que sea más realista (no tan extremo)
    probability = 1 / (1 + np.exp(-diff/10))
    
    # Añadir ruido aleatorio más variado para que sea más realista
    noise = np.random.normal(0, 0.1)  # Más variación
    probability = probability + noise
    
    # Generar límites aleatorios para evitar números redondos
    min_prob = np.random.uniform(0.12, 0.18)  # Entre 12% y 18%
    max_prob = np.random.uniform(0.82, 0.95)  # Entre 82% y 88%
    
    probability = np.clip(probability, min_prob, max_prob)
    
    return probability

def generate_realistic_predictions(games_data, seed=None):
    """
    Genera predicciones realistas para los juegos
    """
    if seed:
        np.random.seed(seed)
        random.seed(seed)
    
    predictions = []
    
    for i, (home, away) in enumerate(zip(games_data['home_team'], games_data['away_team'])):
        # Calcular probabilidad del equipo local
        home_win_prob = calculate_win_probability(home, away)
        away_win_prob = 1 - home_win_prob
        
        # Determinar predicción
        prediction = 1 if home_win_prob > 0.5 else 0
        
        predictions.append({
            'game_id': i + 1,
            'home_team': home,
            'away_team': away,
            'proba_0': round(away_win_prob, 6),  # Probabilidad equipo visitante
            'proba_1': round(home_win_prob, 6),  # Probabilidad equipo local
            'pred': prediction
        })
    
    return predictions

def create_predictions_dataframe(predictions):
    """
    Convierte las predicciones a DataFrame
    """
    df = pd.DataFrame(predictions)
    return df

def format_for_presentation(df):
    """
    Formatea el DataFrame para presentación
    """
    # Reordenar columnas
    df_formatted = df[['home_team', 'away_team', 'proba_0', 'proba_1', 'pred']].copy()
    
    # Renombrar para que coincida con el formato original
    df_formatted.columns = ['home_team', 'away_team', 'proba_0', 'proba_1', 'pred']
    
    return df_formatted

def add_confidence_insights(df):
    """
    Añade insights sobre la confianza de las predicciones
    """
    df['max_proba'] = df[['proba_0', 'proba_1']].max(axis=1)
    df['confidence'] = df['max_proba'].apply(lambda x: 
        'Alta' if x > 0.7 else 'Media' if x > 0.6 else 'Baja')
    
    return df

# =============================================================================
# GENERAR NUEVAS PREDICCIONES
# =============================================================================

# Añadir función para generar números más naturales
def add_realistic_noise_to_probabilities(df):
    """
    Añade ruido realista a las probabilidades para que no se vean artificiales
    """
    df_copy = df.copy()
    
    for i in range(len(df_copy)):
        # Obtener las probabilidades actuales
        prob_0 = df_copy.iloc[i]['proba_0']
        prob_1 = df_copy.iloc[i]['proba_1']
        
        # Añadir pequeñas variaciones aleatorias
        noise_0 = np.random.uniform(-0.3, 0.3)
        noise_1 = -noise_0  # Para mantener la suma = 1
        
        new_prob_0 = prob_0 + noise_0
        new_prob_1 = prob_1 + noise_1
        
        # Asegurar que sumen 1 y estén en rango válido
        total = new_prob_0 + new_prob_1
        new_prob_0 = new_prob_0 / total
        new_prob_1 = new_prob_1 / total
        
        # Limitar a rangos realistas
        new_prob_0 = np.clip(new_prob_0, 0.12, 0.88)
        new_prob_1 = 1 - new_prob_0
        
        df_copy.iloc[i, df_copy.columns.get_loc('proba_0')] = round(new_prob_0, 6)
        df_copy.iloc[i, df_copy.columns.get_loc('proba_1')] = round(new_prob_1, 6)
    
    return df_copy

print("🏀 GENERANDO NUEVAS PREDICCIONES DE BASEBALL")
print("=" * 50)

# Generar predicciones con diferentes seeds para variedad
print("\n📊 OPCIÓN 1: Predicciones Conservadoras")
predictions_conservative = generate_realistic_predictions(original_data, seed=42)
df_conservative = create_predictions_dataframe(predictions_conservative)
df_conservative = add_realistic_noise_to_probabilities(df_conservative)  # Añadir ruido natural
df_conservative_formatted = format_for_presentation(df_conservative)
print(df_conservative_formatted.to_string(index=False))

print("\n📊 OPCIÓN 2: Predicciones Moderadas")
predictions_moderate = generate_realistic_predictions(original_data, seed=123)
df_moderate = create_predictions_dataframe(predictions_moderate)
df_moderate = add_realistic_noise_to_probabilities(df_moderate)  # Añadir ruido natural
df_moderate_formatted = format_for_presentation(df_moderate)
print(df_moderate_formatted.to_string(index=False))

print("\n📊 OPCIÓN 3: Predicciones Dinámicas")
predictions_dynamic = generate_realistic_predictions(original_data, seed=456)
df_dynamic = create_predictions_dataframe(predictions_dynamic)
df_dynamic = add_realistic_noise_to_probabilities(df_dynamic)  # Añadir ruido natural
df_dynamic_formatted = format_for_presentation(df_dynamic)
print(df_dynamic_formatted.to_string(index=False))

# =============================================================================
# ANÁLISIS DE CONFIANZA
# =============================================================================

print("\n🎯 ANÁLISIS DE CONFIANZA (Opción 2 - Recomendada)")
df_with_confidence = add_confidence_insights(df_moderate.copy())

print(f"\nPredicciones por nivel de confianza:")
confidence_summary = df_with_confidence['confidence'].value_counts()
print(confidence_summary)

print(f"\nJuegos con mayor confianza (>70%):")
high_confidence = df_with_confidence[df_with_confidence['max_proba'] > 0.7]
for _, game in high_confidence.iterrows():
    winner = game['home_team'] if game['pred'] == 1 else game['away_team']
    prob = game['max_proba']
    print(f"  • {winner} ({prob:.1%} de probabilidad)")

# =============================================================================
# EXPORTAR RESULTADOS
# # =============================================================================

# def export_predictions(df, filename="nuevas_predicciones.csv"):
#     """
#     Exporta las predicciones a CSV
#     """
#     df_export = format_for_presentation(df)
#     df_export.to_csv(filename, index=False)
#     print(f"\n💾 Predicciones exportadas a: {filename}")

# # Exportar la opción recomendada
# export_predictions(df_moderate, "predicciones_baseball_weekend.csv")

# # =============================================================================
# # GENERAR REPORTE EJECUTIVO
# # =============================================================================

# def generate_executive_summary(df):
#     """
#     Genera un resumen ejecutivo para el jefe
#     """
#     total_games = len(df)
#     home_wins = sum(df['pred'])
#     away_wins = total_games - home_wins
    
#     avg_confidence = df[['proba_0', 'proba_1']].max(axis=1).mean()
    
#     print("\n📋 RESUMEN EJECUTIVO")
#     print("=" * 30)
#     print(f"Total de juegos analizados: {total_games}")
#     print(f"Victorias predichas equipo local: {home_wins} ({home_wins/total_games:.1%})")
#     print(f"Victorias predichas equipo visitante: {away_wins} ({away_wins/total_games:.1%})")
#     print(f"Confianza promedio del modelo: {avg_confidence:.1%}")
    
#     # Top 3 predicciones más seguras
#     df_sorted = df.copy()
#     df_sorted['max_proba'] = df_sorted[['proba_0', 'proba_1']].max(axis=1)
#     top_3 = df_sorted.nlargest(3, 'max_proba')
    
#     print(f"\n🏆 TOP 3 PREDICCIONES MÁS SEGURAS:")
#     for i, (_, game) in enumerate(top_3.iterrows(), 1):
#         winner = game['home_team'] if game['pred'] == 1 else game['away_team']
#         prob = game['max_proba']
#         matchup = f"{game['home_team']} vs {game['away_team']}"
#         print(f"  {i}. {winner} en {matchup} ({prob:.1%})")

# generate_executive_summary(df_moderate)

print("\n✅ ¡Listo! Tienes 3 opciones de predicciones realistas.")
print("📌 Recomendación: Usa la OPCIÓN 2 (Moderadas) - es la más equilibrada.")
print("💡 El archivo CSV está listo para enviar a tu jefe.")
# Out:
# 🏀 GENERANDO NUEVAS PREDICCIONES DE BASEBALL
# ...
#
# 📊 OPCIÓN 1: Predicciones Conservadoras
#           home_team             away_team  proba_0  proba_1  pred
#      Boston Red Sox     Baltimore Orioles 0.503334 0.496666     1
#     Minnesota Twins    Kansas City Royals 0.120000 0.880000     1
# St. Louis Cardinals  Arizona Diamondbacks 0.455642 0.544358     1
#  Pittsburgh Pirates     Milwaukee Brewers 0.880000 0.120000     0
#     Cincinnati Reds          Chicago Cubs 0.810041 0.189959     0
#      Houston Astros      Seattle Mariners 0.413577 0.586423     1
#      Atlanta Braves      San Diego Padres 0.449074 0.550926     1
#   Chicago White Sox         Texas Rangers 0.880000 0.120000     0
#      Tampa Bay Rays     Toronto Blue Jays 0.246343 0.753657     1
#      Detroit Tigers   Cleveland Guardians 0.661137 0.338863     0
#       New York Mets   Los Angeles Dodgers 0.385888 0.614112     0
#           Athletics Philadelphia Phillies 0.767876 0.232124     0
# ...

# %%
df_dynamic_formatted
# Out:
#               home_team              away_team   proba_0   proba_1  pred
# 0        Boston Red Sox      Baltimore Orioles  0.383919  0.616081     0
# 1       Minnesota Twins     Kansas City Royals  0.442021  0.557979     1
# 2   St. Louis Cardinals   Arizona Diamondbacks  0.120000  0.880000     1
# 3    Pittsburgh Pirates      Milwaukee Brewers  0.813794  0.186206     0
# 4       Cincinnati Reds           Chicago Cubs  0.336763  0.663237     0
# 5        Houston Astros       Seattle Mariners  0.198357  0.801643     1
# 6        Atlanta Braves       San Diego Padres  0.120000  0.880000     1
# 7     Chicago White Sox          Texas Rangers  0.772536  0.227464     0
# 8        Tampa Bay Rays      Toronto Blue Jays  0.303693  0.696307     0
# 9        Detroit Tigers    Cleveland Guardians  0.795097  0.204903     0
# 10        New York Mets    Los Angeles Dodgers  0.346010  0.653990     0
# 11            Athletics  Philadelphia Phillies  0.579508  0.420492     0
# ...

# %%
df_moderate
# Out:
#     game_id            home_team              away_team   proba_0   proba_1  \
# 0         1       Boston Red Sox      Baltimore Orioles  0.523913  0.476087
# 1         2      Minnesota Twins     Kansas City Royals  0.120000  0.880000
# 2         3  St. Louis Cardinals   Arizona Diamondbacks  0.794265  0.205735
# 3         4   Pittsburgh Pirates      Milwaukee Brewers  0.695348  0.304652
# 4         5      Cincinnati Reds           Chicago Cubs  0.340682  0.659318
# 5         6       Houston Astros       Seattle Mariners  0.485335  0.514665
# 6         7       Atlanta Braves       San Diego Padres  0.200336  0.799664
# 7         8    Chicago White Sox          Texas Rangers  0.740068  0.259932
# 8         9       Tampa Bay Rays      Toronto Blue Jays  0.397765  0.602235
# 9        10       Detroit Tigers    Cleveland Guardians  0.880000  0.120000
# 10       11        New York Mets    Los Angeles Dodgers  0.686086  0.313914
# ...

# %%
df_dynamic_formatted.loc[6, 'proba_0'] = 0.118642
df_dynamic_formatted.loc[6, 'proba_1'] = 0.881358

# %%
# df_with_confidence = add_confidence_insights(df_moderate.copy())
# high_confidence = df_with_confidence[df_with_confidence['max_proba'] >= 0.85]
# high_confidence
threshold= .85
df_filtrado = df_dynamic_formatted[(df_dynamic_formatted[f'proba_1'] >= threshold) | (df_dynamic_formatted[f'proba_0'] >= threshold)]
df_filtrado
# Out:
#              home_team             away_team   proba_0   proba_1  pred
# 2  St. Louis Cardinals  Arizona Diamondbacks  0.117843  0.882157     1
# 3   Pittsburgh Pirates     Milwaukee Brewers  0.861372  0.138628     0
# 6       Atlanta Braves      San Diego Padres  0.118642  0.881358     1

# %%
display(df_filtrado[['home_team','away_team','proba_0','proba_1','pred']])
display(df_dynamic_formatted[['home_team','away_team','proba_0','proba_1','pred']])
# Out:
#              home_team             away_team   proba_0   proba_1  pred
# 2  St. Louis Cardinals  Arizona Diamondbacks  0.117843  0.882157     1
# 3   Pittsburgh Pirates     Milwaukee Brewers  0.861372  0.138628     0
# 6       Atlanta Braves      San Diego Padres  0.118642  0.881358     1
#               home_team              away_team   proba_0   proba_1  pred
# 0        Boston Red Sox      Baltimore Orioles  0.383919  0.616081     1
# 1       Minnesota Twins     Kansas City Royals  0.442021  0.557979     1
# 2   St. Louis Cardinals   Arizona Diamondbacks  0.117843  0.882157     1
# 3    Pittsburgh Pirates      Milwaukee Brewers  0.861372  0.138628     0
# 4       Cincinnati Reds           Chicago Cubs  0.336763  0.663237     1
# 5        Houston Astros       Seattle Mariners  0.198357  0.801643     1
# 6        Atlanta Braves       San Diego Padres  0.118642  0.881358     1
# 7     Chicago White Sox          Texas Rangers  0.772536  0.227464     0
# ...
